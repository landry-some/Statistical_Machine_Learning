# %%
import pandas as pd

# %%
df = pd.read_csv("HR_comma_sep.csv")
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df[df['left'] == 1].shape[0]
# Out:
# 3571

# %%
#These many left

# %%
df[df['left'] == 0].shape[0]
# Out:
# 11428

# %%
#These many did not left

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.crosstab(df.salary,df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='salary'>

# %%
left_by_salary = df[df['left'] == 1]['salary'].value_counts()
# left_by_salary
left_by_salary.plot(kind = 'bar')
plt.xlabel('Salary Level')
plt.ylabel('Number of Employees Who Left')
plt.show()

# %%
left_dept_wise = df[df['left'] == 1]['Department'].value_counts()
left_dept_wise
# Out:
# Department
# sales          1014
# technical       697
# support         555
# IT              273
# hr              215
# accounting      204
# marketing       203
# product_mng     198
# RandD           121
# management       91
# Name: count, dtype: int64

# %%
left_dept_wise.plot(kind='bar',color='tomato')
plt.ylabel('Number of Employees')
# Out:
# Text(0, 0.5, 'Number of Employees')

# %%
from sklearn.model_selection import train_test_split

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['satisfaction_level','time_spend_company','last_evaluation']],df.left)

# %%
X_train
# Out:
#        satisfaction_level  time_spend_company  last_evaluation
# 14785                0.37                   3             0.49
# 12922                0.57                   2             0.91
# 1953                 0.43                   3             0.57
# 10572                0.66                   3             0.66
# 8966                 0.51                   2             0.91
# ...                   ...                 ...              ...
# 9794                 0.78                   3             0.54
# 12572                0.75                   6             0.97
# 5206                 0.89                   2             0.89
# 8306                 0.27                   6             0.48
# 34                   0.84                   6             0.87
#
# [11249 rows x 3 columns]

# %%
X_test
# Out:
#        satisfaction_level  time_spend_company  last_evaluation
# 6306                 1.00                   4             0.81
# 1542                 0.44                   3             0.52
# 1322                 0.78                   5             0.86
# 5327                 0.65                   3             0.52
# 2589                 0.82                   3             0.59
# ...                   ...                 ...              ...
# 7868                 0.33                   2             0.72
# 14439                0.85                   5             0.95
# 11694                0.16                   5             0.96
# 8011                 0.66                   2             0.93
# 4227                 0.67                   3             0.67
#
# [3750 rows x 3 columns]

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.7690666666666667
